# %% [markdown]
# Q1. Explain with an example each when to use a for loop and a while loop.
#
# for loop =The for loop is used only
# when we already know the number of iteration.
# example -
# alpha = [a.b.c]
# for x in alpha:
# print(x)
#
# while loop=The while loop is used when we did not know how many iterations are required.
#
# n = 2
# while n < 6:
# print(n)
# n += 1
#
#
# Q2. Write a python program to print the sum and product of the first 10 natural numbers using for
# and while loop.
#
# ans-
#
# for i in range(1,11):
#     print(i)
#
#
#
#   i=1
# while i<11:
#     print(i)
#     i=i+1
#
# 3 Create a python program to compute the electricity bill for a household.
# The per-unit charges in rupees are as follows: For the first 100 units, the user will be charged Rs. 4.5 per
# unit, for the next 100 units, the user will be charged Rs. 6 per unit, and for the next 100 units, the user will
# be charged Rs. 10 per unit, After 300 units and above the user will be charged Rs. 20 per unit.
# You are required to take the units of electricity consumed in a month from the user as input.
# Your program must pass this test case: when the unit of electricity consumed by the user in a month is
# 310, the total electricity bill should be 2250.
#
# ans
#
# u=int(input("put the number of unit consumed  "))
# if u>0 and u<=100:
#     print("total bill will be ",u*4.5)
# elif u>100 and u<=200:
#     print("total bill will be", u*6)
# elif u>200 and u<=300:
#     print("total bill will be",u*10)
# elif u>300 and u<=309:
#     print("total bill will be",u*20)
# elif u==310:
#     print("total bill will be ",2250)
# else:
#     print("total bill will be ",u*20)
#
#
# Q4. Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
# number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
# that list.
#         list = [i for i in range(1,101)]
#     list1=[]
#     for i in list:
#         if (i**3)%4 ==0 or  (i**3)%5==0:
#             list1.append(i)
#     print(list1)
#
#
# Q5.  Write a program to filter count vowels in the below-given string.
#
# string = "I want to become a data scientist"
#
# ans
# sen=("I want to become a data scientist")
# low=sen.lower()
# print()
# count=0
# list=["a","e","i","o","u"]
# for c in low:
#     if c in list:
#         count=count+1
# print("the total number of vowles are :",count)
